# %%
import pandas as pd
import numpy as np

# %%
df0=pd.read_excel(r'C:\Users\lenovo\Desktop\ironhack\Projects\Data cleaning project\3-Bank Deposit.xlsx')

# %%
df0
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       95       retired  divorced    primary      no   2282.0      no   no
# 1       95       retired   married  secondary      no      0.0      no   no
# 2       94       retired  divorced  secondary      no   1234.0      no   no
# 3       93       retired   married    unknown      no    775.0      no   no
# 4       93       retired   married    unknown      no    775.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 11217   50  entrepreneur  divorced   tertiary      no    315.0      no   no
# 11218   50    management   married   tertiary      no   2881.0      no   no
# 11219   50    technician  divorced  secondary      no      0.0     yes   no
# 11220   50      services   married  secondary      no   2376.0     yes   no
# 11221   50    management   married   tertiary      no   8205.0     yes   no
#
# ...

# %%
df0.reset_index(inplace=True)

# %%
df0
# Out:
#        index  age           job   marital  education default  balance housing  \
# 0          0   95       retired  divorced    primary      no   2282.0      no
# 1          1   95       retired   married  secondary      no      0.0      no
# 2          2   94       retired  divorced  secondary      no   1234.0      no
# 3          3   93       retired   married    unknown      no    775.0      no
# 4          4   93       retired   married    unknown      no    775.0      no
# ...      ...  ...           ...       ...        ...     ...      ...     ...
# 11217  11217   50  entrepreneur  divorced   tertiary      no    315.0      no
# 11218  11218   50    management   married   tertiary      no   2881.0      no
# 11219  11219   50    technician  divorced  secondary      no      0.0     yes
# 11220  11220   50      services   married  secondary      no   2376.0     yes
# 11221  11221   50    management   married   tertiary      no   8205.0     yes
#
# ...

# %%
df0.rename(columns={'index':'CustomerID'},inplace=True)

# %%
contains_null=df0.isnull().sum()
contains_null
# Out:
# CustomerID               0
# age                      0
# job                      0
# marital                  6
# education               27
# default                  6
# balance                  6
# housing                  6
# loan                    12
# contact                  6
# day                      6
# month                    8
# duration                 8
# campaign                 8
# pdays                    8
# previous                 6
# poutcome                 0
# Bank deposit(target)     0
# dtype: int64

# %%
contains_null.sum()
# Out:
# 113

# %%
data1=df0

# %%
data1.describe().transpose()
# Out:
#               count         mean            std     min      25%     50%  \
# CustomerID  11222.0  5610.500000    3239.656695     0.0  2805.25  5610.5
# age         11222.0    56.411068       6.141462    50.0    52.00    55.0
# balance     11216.0  7966.974412  642145.646918 -4057.0   108.00   627.5
# day         11216.0    15.786912       8.336913     1.0     8.00    16.0
# duration    11214.0  2040.672106  188861.984549     0.0   102.00   176.0
# campaign    11214.0     2.737739       2.854410     1.0     1.00     2.0
# pdays       11214.0    35.118245      90.776604    -1.0    -1.00    -1.0
# previous    11216.0     0.558934       1.741345     0.0     0.00     0.0
#
#                 75%         max
# CustomerID  8415.75     11221.0
# age           58.00        95.0
# balance     2031.75  68000000.0
# day           21.00        31.0
# duration     316.00  20000000.0
# campaign       3.00        43.0
# pdays         -1.00       792.0
# previous       0.00        37.0

# %%
data1.loc[data1['marital'].isna()] #when I check the rows with marital is NA, I can see that there is too many missing
#values in rows 134 to 139. I can delete these rows, knowing that over the 11000+ total rows, the loss will be negligible
# Out:
#      CustomerID  age        job marital education default  balance housing  \
# 134         134   80  housemaid     NaN       NaN     NaN      NaN     NaN
# 135         135   80    retired     NaN       NaN     NaN      NaN     NaN
# 136         136   80    retired     NaN       NaN     NaN      NaN     NaN
# 137         137   80    retired     NaN       NaN     NaN      NaN     NaN
# 138         138   80    retired     NaN       NaN     NaN      NaN     NaN
# 139         139   80    retired     NaN       NaN     NaN      NaN     NaN
#
#     loan contact  day month  duration  campaign  pdays  previous poutcome  \
# 134  NaN     NaN  NaN   NaN       NaN       NaN    NaN       NaN  failure
# 135  NaN     NaN  NaN   NaN       NaN       NaN    NaN       NaN  unknown
# 136  NaN     NaN  NaN   NaN       NaN       NaN    NaN       NaN  success
# 137  NaN     NaN  NaN   NaN       NaN       NaN    NaN       NaN  unknown
# ...

# %%
data1.drop(data1.index[134:140],inplace=True)

# %%
contains_null=data1.isnull().sum()
contains_null
# Out:
# CustomerID               0
# age                      0
# job                      0
# marital                  0
# education               21
# default                  0
# balance                  0
# housing                  0
# loan                     6
# contact                  0
# day                      0
# month                    2
# duration                 2
# campaign                 2
# pdays                    2
# previous                 0
# poutcome                 0
# Bank deposit(target)     0
# dtype: int64

# %%
data1['education'].unique()
# Out:
# array(['primary', 'secondary', 'unknown', 'tertiary', nan, 'hjkl',
#        'Tertiary'], dtype=object)

# %%
replace_dict = {'hjkl' : 'unknown', 'Tertiary' : 'tertiary'}
data1 = data1.replace(replace_dict)

# %%
data1['education'].fillna('unknown',inplace=True)

# %%
data1['education'].unique()
# Out:
# array(['primary', 'secondary', 'unknown', 'tertiary'], dtype=object)

# %%
data1['marital'].unique()
# Out:
# array(['divorced', 'married', 'single', 'DIV'], dtype=object)

# %%
data1 = data1.replace({'DIV':'divorced'})

# %%
contains_null
# Out:
# CustomerID               0
# age                      0
# job                      0
# marital                  0
# education               21
# default                  0
# balance                  0
# housing                  0
# loan                     6
# contact                  0
# day                      0
# month                    2
# duration                 2
# campaign                 2
# pdays                    2
# previous                 0
# poutcome                 0
# Bank deposit(target)     0
# dtype: int64

# %%
data1

# %%
data1['previous'].unique()
# Out:
# array([ 0.,  7.,  9.,  3.,  1.,  4.,  2.,  8., 12., 11., 13.,  6., 15.,
#         5., 20., 16., 17., 10., 21., 18., 27., 19., 29., 14., 23., 37.])

# %%
data1.describe().transpose()
# Out:
#               count         mean            std     min      25%     50%  \
# CustomerID  11216.0  5613.428317    3238.047389     0.0  2809.75  5613.5
# age         11216.0    56.398449       6.118814    50.0    52.00    55.0
# balance     11216.0  7966.974412  642145.646918 -4057.0   108.00   627.5
# day         11216.0    15.786912       8.336913     1.0     8.00    16.0
# duration    11214.0  2040.672106  188861.984549     0.0   102.00   176.0
# campaign    11214.0     2.737739       2.854410     1.0     1.00     2.0
# pdays       11214.0    35.118245      90.776604    -1.0    -1.00    -1.0
# previous    11216.0     0.558934       1.741345     0.0     0.00     0.0
#
#                 75%         max
# CustomerID  8417.25     11221.0
# age           58.00        95.0
# balance     2031.75  68000000.0
# day           21.00        31.0
# duration     316.00  20000000.0
# campaign       3.00        43.0
# pdays         -1.00       792.0
# previous       0.00        37.0

# %%
data1['previous'].value_counts()
#Given that 0 previous loans is overwhelmingly the mode of the column 'previous', we will replace the 1 missing value by 0
# Out:
# 0.0     9211
# 1.0      634
# 2.0      502
# 3.0      323
# 4.0      158
# 5.0      117
# 6.0       71
# 7.0       59
# 8.0       36
# 9.0       25
# 11.0      19
# 10.0      15
# 12.0      13
# 13.0       8
# 15.0       4
# 14.0       4
# 19.0       3
# 16.0       3
# 20.0       2
# 18.0       2
# 23.0       2
# 21.0       1
# 29.0       1
# 17.0       1
# 27.0       1
# 37.0       1
# Name: previous, dtype: int64

# %%
data1['previous'].fillna(0,inplace=True)

# %%
contains_null
# Out:
# CustomerID               0
# age                      0
# job                      0
# marital                  0
# education               21
# default                  0
# balance                  0
# housing                  0
# loan                     6
# contact                  0
# day                      0
# month                    2
# duration                 2
# campaign                 2
# pdays                    2
# previous                 0
# poutcome                 0
# Bank deposit(target)     0
# dtype: int64

# %%
data1['pdays'].value_counts() #same thing here, we will replace missing values by the mode (-1)
# Out:
# -1.0      9210
#  92.0       58
#  182.0      58
#  181.0      55
#  91.0       53
#           ...
#  157.0       1
#  26.0        1
#  459.0       1
#  686.0       1
#  417.0       1
# Name: pdays, Length: 389, dtype: int64

# %%
data1['pdays'].fillna(-1,inplace=True)

# %%
print('median: ',data1['campaign'].median(), 'mean: ',data1['campaign'].mean(),'mode: ',data1['campaign'].mode()) 
#here we can see the distribution is more balanced, and although the mode is 1, the median and mean are closer to 2. 
#We will replace na by 2
# Out:
# median:  2.0 mean:  2.737738541109328 mode:  0    1.0
# dtype: float64

# %%
data1['campaign'].fillna(2,inplace=True)

# %%
data1['duration'].value_counts()
# Out:
# 123.0     60
# 97.0      59
# 122.0     56
# 104.0     56
# 124.0     55
#           ..
# 1417.0     1
# 1008.0     1
# 928.0      1
# 552.0      1
# 1361.0     1
# Name: duration, Length: 1096, dtype: int64

# %%
print('median: ',data1['duration'].median(), 'mean: ',data1['duration'].mean(),'mode: ',data1['duration'].mode())
# Out:
# median:  176.0 mean:  2040.6721062957017 mode:  0    123.0
# dtype: float64

# %%
data1['duration'].max()
#For the duration I can see that the mean is very high. Therefore I checked the max, which is clearly unrealistic.
#So let's check about this outlier
# Out:
# 20000000.0

# %%
data1.loc[data1['loan'].isna()] 
#This outlier is also included in rows where education is unknown. Plus, it is hard to guess if they have already 
#a loan. Given it is only 6 rows over 10000+, we will drop them
# Out:
#     CustomerID  age      job   marital education default  balance housing  \
# 37          37   84  retired   married   unknown      no   1791.0      no
# 38          38   84  retired   married   unknown      no  81204.0      no
# 39          39   84  retired  divorced   unknown      no   2619.0      no
# 40          40   84  retired   married   unknown      no  81204.0      no
# 41          41   84  retired  divorced   unknown      no    639.0      no
# 42          42   84  retired  divorced   primary      no   1680.0      no
#
#    loan    contact   day month    duration  campaign  pdays  previous  \
# 37  NaN  telephone  30.0   oct        62.0       3.0   -1.0       0.0
# 38  NaN  telephone  28.0   dec  20000000.0       1.0  313.0       2.0
# 39  NaN  telephone   8.0   feb       145.0       2.0  115.0       2.0
# 40  NaN  telephone   1.0   apr       390.0       1.0   94.0       3.0
# 41  NaN  telephone  18.0   may       353.0       3.0   -1.0       0.0
# ...

# %%
data1.drop(data1.index[37:43],inplace=True)

# %%
data1.loc[data1['month'].isna()]
# Out:
#      CustomerID  age      job  marital  education default  balance housing  \
# 232         232   77  retired  married  secondary      no   4112.0      no
# 233         233   77  retired  married   tertiary      no   7802.0      no
#
#     loan    contact   day month  duration  campaign  pdays  previous poutcome  \
# 232   no  telephone  26.0   NaN       NaN       2.0   -1.0       2.0  success
# 233   no  telephone   1.0   NaN       NaN       2.0   -1.0       0.0  unknown
#
#     Bank deposit(target)
# 232                  yes
# 233                  yes

# %%
data1.drop([232,233],inplace=True)

# %%
contains_null=data1.isnull().sum()
contains_null
# Out:
# CustomerID              0
# age                     0
# job                     0
# marital                 0
# education               0
# default                 0
# balance                 0
# housing                 0
# loan                    0
# contact                 0
# day                     0
# month                   0
# duration                0
# campaign                0
# pdays                   0
# previous                0
# poutcome                0
# Bank deposit(target)    0
# dtype: int64

# %%
#No missing values. Let's now work on the outliers.
#We will work with data2 
data2=data1

# %%
stats = data2.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#               count         mean            std     min      25%     50%  \
# CustomerID  11208.0  5617.372413    3235.833613     0.0  2815.75  5617.5
# age         11208.0    56.379996       6.081336    50.0    52.00    55.0
# balance     11208.0  7956.507316  642374.043239 -4057.0   108.00   627.0
# day         11208.0    15.787652       8.334247     1.0     8.00    16.0
# duration    11208.0   257.230014     260.958116     0.0   102.00   176.0
# campaign    11208.0     2.737866       2.854989     1.0     1.00     2.0
# pdays       11208.0    35.081995      90.754938    -1.0    -1.00    -1.0
# previous    11208.0     0.558262       1.741477     0.0     0.00     0.0
#
#                 75%         max     IQR
# CustomerID  8419.25     11221.0  5603.5
# age           58.00        95.0     6.0
# balance     2027.00  68000000.0  1919.0
# day           21.00        31.0    13.0
# duration     316.00      4918.0   214.0
# campaign       3.00        43.0     2.0
# ...

# %%
#We notice that the IQR (Interquartile Range) is especially high for the column balance. 
#Indeed, we should have a closer look at this columns, and the max value of 68000000 euros

# %%
data2.loc[data2['balance']==68000000]
# Out:
#      CustomerID  age      job  marital education default     balance housing  \
# 231         231   77  retired  married   primary      no  68000000.0      no
#
#     loan    contact   day month  duration  campaign  pdays  previous poutcome  \
# 231   no  telephone  27.0   nov     341.0       4.0   94.0       3.0  failure
#
#     Bank deposit(target)
# 231                   no

# %%
#We see that this outlier has no loan, and that the previous outcome was failure, and is not even a bank target.
#And honestly, nobody that rich needs a term deposit.

# %%
data2.drop([231],inplace=True)

# %%
stats = data2.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#               count         mean           std     min     25%     50%  \
# CustomerID  11207.0  5617.853038   3235.577886     0.0  2816.5  5618.0
# age         11207.0    56.378157      6.078487    50.0    52.0    55.0
# balance     11207.0  1889.580976  10241.758297 -4057.0   108.0   627.0
# day         11207.0    15.786651      8.333946     1.0     8.0    16.0
# duration    11207.0   257.222539    260.968560     0.0   102.0   176.0
# campaign    11207.0     2.737753      2.855092     1.0     1.0     2.0
# pdays       11207.0    35.076738     90.757281    -1.0    -1.0    -1.0
# previous    11207.0     0.558044      1.741402     0.0     0.0     0.0
#
#                75%        max     IQR
# CustomerID  8419.5    11221.0  5603.0
# age           58.0       95.0     6.0
# balance     2027.0  1000000.0  1919.0
# day           21.0       31.0    13.0
# duration     316.0     4918.0   214.0
# campaign       3.0       43.0     2.0
# pdays         -1.0      792.0     0.0
# ...

# %%
data2.loc[data2['pdays']==-1]
# Out:
#        CustomerID  age         job   marital  education default  balance  \
# 0               0   95     retired  divorced    primary      no   2282.0
# 1               1   95     retired   married  secondary      no      0.0
# 2               2   94     retired  divorced  secondary      no   1234.0
# 5               5   92     retired   married    unknown      no    775.0
# 7               7   90     retired  divorced  secondary      no      1.0
# ...           ...  ...         ...       ...        ...     ...      ...
# 11209       11209   50  technician   married   tertiary      no   1830.0
# 11211       11211   50      admin.   married  secondary      no   2971.0
# 11212       11212   50  technician    single   tertiary      no      2.0
# 11213       11213   50      admin.   married  secondary      no    100.0
# 11220       11220   50    services   married  secondary      no   2376.0
#
#       housing loan    contact   day month  duration  campaign  pdays  \
# ...

# %%
data2.loc[data2['pdays']==792]
# Out:
#       CustomerID  age      job  marital  education default  balance housing  \
# 1950        1950   60  retired  married  secondary      no    975.0      no
#
#      loan   contact   day month  duration  campaign  pdays  previous poutcome  \
# 1950   no  cellular  16.0   sep     303.0       1.0  792.0       1.0  failure
#
#      Bank deposit(target)
# 1950                  yes

# %%
data2['contact'].value_counts()
# Out:
# cellular     6814
# unknown      2969
# telephone    1423
# ghjk            1
# Name: contact, dtype: int64

# %%
data2['contact'].replace({'ghjk':'cellular'},inplace=True)

# %%
data2['poutcome'].value_counts() #too many unknown/other values, the column is not usable
# Out:
# unknown    9208
# failure    1142
# success     481
# other       375
# Name: poutcome, dtype: int64

# %%
data2.drop(columns='poutcome',inplace=True)

# %%
data2
# Out:
#        CustomerID  age           job   marital  education default  balance  \
# 0               0   95       retired  divorced    primary      no   2282.0
# 1               1   95       retired   married  secondary      no      0.0
# 2               2   94       retired  divorced  secondary      no   1234.0
# 3               3   93       retired   married    unknown      no    775.0
# 4               4   93       retired   married    unknown      no    775.0
# ...           ...  ...           ...       ...        ...     ...      ...
# 11217       11217   50  entrepreneur  divorced   tertiary      no    315.0
# 11218       11218   50    management   married   tertiary      no   2881.0
# 11219       11219   50    technician  divorced  secondary      no      0.0
# 11220       11220   50      services   married  secondary      no   2376.0
# 11221       11221   50    management   married   tertiary      no   8205.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.array(data2['balance']))

# %%
data2.loc[data2['balance']==1000000]
# Out:
#     CustomerID  age      job  marital  education default    balance housing  \
# 17          17   87  retired  married  secondary      no  1000000.0      no
#
#    loan    contact   day month  duration  campaign  pdays  previous poutcome  \
# 17   no  telephone  15.0   dec     150.0       1.0   -1.0       0.0  unknown
#
#    Bank deposit(target)
# 17                   no

# %%
data2.drop(index=[17],inplace=True)

# %%
data2['marital'].unique()
# Out:
# array(['divorced', 'married', 'single'], dtype=object)

# %%
data2.rename(columns={'Bank deposit(target)':'target'},inplace=True) #renaming the column to avoid parenthesis issues in mysql

# %%
pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:Ironhack87++@localhost:3306/bank')

# %%
data2.to_sql('bank_deposit',engine,if_exists='replace')

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

# %%
f, ax = plt.subplots(1,2, figsize=(18,8))
colors = ["#BA5545", "#5CAFB5"]
labels ="Did not Open", "Opened"
plt.suptitle('Success/Failure analysis', fontsize=20)
data1["target"].value_counts().plot.pie(explode=[0,0.25], autopct='%1.2f%%', ax=ax[0], shadow=True, colors=colors, labels=labels, fontsize=12, startangle=25)
ax[0].set_ylabel('', fontsize=14, )
palette = ["#5CAFB5", "#BA5545"]
sns.barplot(x="job", y="balance", hue="target", data=data1, palette=palette, estimator=lambda x: len(x) / len(data1) * 100)
ax[1].set(ylabel="(%)")
ax[1].set_xticklabels(data1["job"].unique(), rotation=30)
plt.show()
